# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating random dataset for testing my model....
from sklearn.datasets import make_regression
X,y = make_regression(
    n_samples=100,
    n_features=2,
    noise=10,
    random_state=12
)
# plt.scatter(X,y,color='blue')
# plt.show()

# %%
# Using sklearn Metrics to verify my metrics
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test  = train_test_split(X,y,test_size=0.2,random_state=12)
lr = LinearRegression()
lr.fit(X_train,y_train)

y_pred = lr.predict(X_test)

MAE = mean_absolute_error(y_test,y_pred)
print(f"Mean Absolute Error is:- {MAE}")
# Out:
# Mean Absolute Error is:- 8.376771143918868

# %%
# Using my own metrics
def mean_absolute_errorr(y_test,y_pred):
    MAE = 0
    for i in range(y_test.shape[0]):
        if((y_test[i] - y_pred[i]) >= 0):
            MAE += ((y_test[i] - y_pred[i])) / y_test.shape[0]

        else:
            MAE += ((y_pred[i] - y_test[i])) / y_test.shape[0]
    return MAE

MAE1 = mean_absolute_errorr(y_test,y_pred)
print(f"Mean Absolute Error is:- {MAE1}")
# Out:
# Mean Absolute Error is:- 8.376771143918868

# %%
import MyML.src.utils as Utils

Utils.mean_absolute_error(y_test,y_pred)
# Out:
# np.float64(8.376771143918868)

# %%
# Cheking linear Regression in Scikit Learn...
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train,y_train)

print(lr.coef_,lr.intercept_)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating random dataset for testing my model....
from sklearn.datasets import make_regression
X,y = make_regression(
    n_samples=100,
    n_features=2,
    noise=10,
    random_state=12
) 
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test  = train_test_split(X,y,test_size=0.2,random_state=12)
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train,y_train)

print(lr.coef_,lr.intercept_)
# Out:
# [ 2.44375984 16.54786396] -1.7226937969510323

# %%
from MyML.src.linear_model import LinearRegression as mylr

glr = mylr(solver='gd')

print(glr.fit(X_train,y_train))
# Out:
# Epochs: 50, Weights: [ 1.33478404 10.96959746] , Intercept: -1.947603654147625
# Epochs: 100, Weights: [ 1.80179497 14.47582777] , Intercept: -2.1552204182844106
# Epochs: 150, Weights: [ 2.10896565 15.74966451] , Intercept: -2.0280793594412247
# Epochs: 200, Weights: [ 2.27776345 16.22921999] , Intercept: -1.8976290737369375
# Epochs: 250, Weights: [ 2.36369585 16.4164493 ] , Intercept: -1.8143519003578477
# Epochs: 300, Weights: [ 2.40575889 16.49213108] , Intercept: -1.7685067237101049
# Epochs: 350, Weights: [ 2.42589817 16.5236856 ] , Intercept: -1.7449676899899766
# Epochs: 400, Weights: [ 2.43541494 16.53718849] , Intercept: -1.7333385986852867
# Epochs: 450, Weights: [ 2.43987602 16.54308781] , Intercept: -1.727724977273994
# Epochs: 500, Weights: [ 2.44195668 16.54570646] , Intercept: -1.7250544663322018
# Epochs: 550, Weights: [ 2.442924   16.54688262] , Intercept: -1.723796058915042
# Epochs: 600, Weights: [ 2.4433728  16.54741542] , Intercept: -1.723206785867647
# ...

# %%
# Testing the polynomial regression

import numpy as np

np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 2 + 5 * X + 8 * X**2 + np.random.randn(100, 1)   

import matplotlib.pyplot as plt
plt.scatter(X,y)

from MyML.src.linear_model import PolynomialRegression
pr = PolynomialRegression(degree=2)
pr.fit(X,y)

pr.predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 16
#      13 pr = PolynomialRegression(degree=2)
#      14 pr.fit(X,y)
# ---> 16 pr.predict(X)
#
# File m:\WOC_Fina;\MachineLearningLibrary\MyML\src\linear_model.py:116, in PolynomialRegression.predict(self, X_test)
#     113 X_poly = self.polynomial_transfrom(X_test)
#     115 # Returning the predicted value..... :)
# --> 116 return X_poly * self.weights
#
# ValueError: operands could not be broadcast together with shapes (100,3) (3,1)
