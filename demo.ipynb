# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating random dataset for testing my model....
from sklearn.datasets import make_regression
X,y = make_regression(
    n_samples=100,
    n_features=2,
    noise=10,
    random_state=12
) 
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test  = train_test_split(X,y,test_size=0.2,random_state=12)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating random dataset for testing my model....
from sklearn.datasets import make_regression
X,y = make_regression(
    n_samples=100,
    n_features=2,
    noise=10,
    random_state=12
) 
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test  = train_test_split(X,y,test_size=0.2,random_state=12)
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train,y_train)

print(lr.coef_,lr.intercept_)
# Out:
# [ 2.44375984 16.54786396] -1.7226937969510323

# %%
from MyML.src.linear_model import LinearRegression as mylr

glr = mylr(solver='gd')

print(glr.fit(X_train,y_train))
# Out:
# (array([ -11.42252573, 3201.28474473]), np.float64(-779.4192623845187))
